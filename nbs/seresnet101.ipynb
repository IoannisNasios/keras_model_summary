# %%
# !pip install image-classifiers

# %%
from classification_models import Classifiers
# Out:
# Using TensorFlow backend.

# %%
img_shape=(224,224,3)
classifier, preprocess_input = Classifiers.get('seresnet101')
model = classifier(input_shape=img_shape, weights=None, include_top=True)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input (InputLayer)              (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_262 (ZeroPadding (None, 230, 230, 3)  0           input[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d_262[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 112, 112, 64) 256         conv2d_134[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 112, 112, 64) 0           batch_normalization_54[0][0]
# ...
