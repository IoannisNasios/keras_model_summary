# %%
# !pip install image-classifiers

# %%
from classification_models import Classifiers
# Out:
# Using TensorFlow backend.

# %%
img_shape=(224,224,3)
classifier, preprocess_input = Classifiers.get('seresnet34')
model = classifier(input_shape=img_shape, weights=None, include_top=True)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# data (InputLayer)               (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 224, 224, 3)  9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_210 (ZeroPadding (None, 230, 230, 3)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 112, 112, 64) 9408        zero_padding2d_210[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 112, 112, 64) 256         conv0[0][0]
# ...
